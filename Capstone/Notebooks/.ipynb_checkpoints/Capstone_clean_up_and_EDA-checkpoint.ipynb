# %% [markdown]
# # Capstone Data clean-up and EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import numpy as np
import datetime as dt

# %%
beatles = pd.read_csv('beatles_precision.csv')

# %%
beatles.head()
# Out:
#    Unnamed: 0                                        song       artist  \
# 0           0              Love Me Do - Mono / Remastered  The Beatles
# 1           1          From Me To You - Mono / Remastered  The Beatles
# 2           2           She Loves You - Mono / Remastered  The Beatles
# 3           3  I Want To Hold Your Hand - Remastered 2015  The Beatles
# 4           4         Can't Buy Me Love - Remastered 2015  The Beatles
#
#             album  duration  track_num release_date  popularity  danceability  \
# 0  1 (Remastered)    140173          1   2000-11-13          57         0.524
# 1  1 (Remastered)    116160          2   2000-11-13          59         0.581
# 2  1 (Remastered)    140920          3   2000-11-13          66         0.377
# 3  1 (Remastered)    145746          4   2000-11-13          71         0.490
# 4  1 (Remastered)    131213          5   2000-11-13          56         0.426
#
#    energy  key  key_confidence  mode  speechiness  acousticness  \
# 0   0.880    0           0.563     1       0.0987         0.404
# 1   0.821    0           0.000     1       0.0318         0.507
# 2   0.916    4           0.000     0       0.0481         0.260
# 3   0.715    7           0.560     1       0.0476         0.386
# 4   0.760    0           0.712     1       0.0414         0.118
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000191     0.154    0.758  148.058
# 1          0.000000     0.108    0.968  136.145
# 2          0.000000     0.074    0.912   75.533
# 3          0.000000     0.311    0.866  130.726
# 4          0.000000     0.325    0.955  171.838

# %% [markdown]
# #### data cleaning

# %%
## remove pesky 'remastered' bits from album and song titles
beatles['song'] = beatles['song'].str.replace(r' - [a-zA-Z]+ \d+', '', regex=True)

# %%
beatles['song'] = beatles['song'].str.replace(' - Mono / Remastered', '')

# %%
beatles['album'] = beatles['album'].str.replace('(Remastered)', '')

# %%
beatles['album'] = beatles['album'].str[:-3]

# %%
## remove duplicates from the lone greatist hits that has important non-LP tracks
len(beatles)
# Out:
# 220

# %%
beatles.drop_duplicates(subset='song', keep = 'last', inplace = True)

# %%
len(beatles)
# Out:
# 201

# %%
beatles.loc[beatles.song == 'Yellow Submarine']
# Out:
#      Unnamed: 0              song       artist     album  duration  track_num  \
# 128         128  Yellow Submarine  The Beatles  Revolver    158880          6
#
#     release_date  popularity  danceability  energy  key  key_confidence  mode  \
# 128   1966-08-05          63         0.604   0.549    1           0.738     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 128       0.0389         0.531               0.0     0.438    0.696  111.398

# %%
## remove George Martin credited tracks
beatles = beatles.drop(beatles[beatles.artist == 'George Martin'].index)

# %%
## Change release_date to year, as precise date is not too relevant
beatles['release_date'] = pd.to_datetime(beatles['release_date'])

# %%
beatles['release_date'] = beatles['release_date'].dt.year

# %%
beatles.head()
# Out:
#     Unnamed: 0                      song       artist album  duration  \
# 1            1            From Me To You  The Beatles     1    116160
# 2            2             She Loves You  The Beatles     1    140920
# 3            3  I Want To Hold Your Hand  The Beatles     1    145746
# 6            6               I Feel Fine  The Beatles     1    139346
# 11          11               Day Tripper  The Beatles     1    169000
#
#     track_num  release_date  popularity  danceability  energy  key  \
# 1           2          2000          59         0.581   0.821    0
# 2           3          2000          66         0.377   0.916    4
# 3           4          2000          71         0.490   0.715    7
# 6           7          2000          63         0.564   0.827    7
# 11         12          2000          64         0.665   0.782    6
#
#     key_confidence  mode  speechiness  acousticness  instrumentalness  \
# 1            0.000     1       0.0318        0.5070          0.000000
# 2            0.000     0       0.0481        0.2600          0.000000
# 3            0.560     1       0.0476        0.3860          0.000000
# 6            1.000     1       0.0283        0.0904          0.000004
# 11           0.521     0       0.0307        0.1200          0.000004
#
#     liveness  valence    tempo
# 1      0.108    0.968  136.145
# 2      0.074    0.912   75.533
# 3      0.311    0.866  130.726
# 6      0.127    0.912   89.847
# 11     0.125    0.731  137.453

# %%
## Dictonary to plot keys and modes

key_dict = {
    0: "C",
    1: "Db",
    2: "D",
    3: "Eb",
    4: "E",
    5: "F",
    6: "F#",
    7: "G",
    8: "Ab",
    9: "A",
    10: "Bb",
    11: "B"
}

mode_dict = {
    0: "Minor",
    1: "Major"
}

# %%
## change duration from ms to mm:ss format

# %%
credits = pd.read_csv('credits.csv')

# %%
## convert all titles to uppercase to allow for more accurate matching keys
beatles.song = beatles.song.str.upper()
credits.Song = credits.Song.str.upper()

# %%
merge = pd.merge(beatles, credits,
                left_on='song', right_on='Song',
                how='left')

# %%
merge.to_csv("merge.csv", sep = ',')

# %%
## export merge to excel for some pesky changes, i.e. capturing a few unsuccessful joins and
## correcting dates from greatist hits

# %%
beatles_new = pd.read_csv('../data/merge_revised.csv')

# %%
beatles_new
# Out:
#      Unnamed: 0                          song       artist             album  \
# 0             0                FROM ME TO YOU  The Beatles                 1
# 1             1                 SHE LOVES YOU  The Beatles                 1
# 2             2      I WANT TO HOLD YOUR HAND  The Beatles                 1
# 3             3                   I FEEL FINE  The Beatles                 1
# 4             4                   DAY TRIPPER  The Beatles                 1
# ..          ...                           ...          ...               ...
# 189         190                 BABY IT'S YOU  The Beatles  Please Please Me
# 190         191  DO YOU WANT TO KNOW A SECRET  The Beatles  Please Please Me
# 191         192              A TASTE OF HONEY  The Beatles  Please Please Me
# 192         193               THERE'S A PLACE  The Beatles  Please Please Me
# 193         194               TWIST AND SHOUT  The Beatles  Please Please Me
#
#      duration  track_num  release_date  popularity  danceability  energy  ...  \
# 0      116160          2          1963          59         0.581   0.821  ...
# 1      140920          3          1963          66         0.377   0.916  ...
# 2      145746          4          1963          71         0.490   0.715  ...
# 3      139346          7          1964          63         0.564   0.827  ...
# 4      169000         12          1965          64         0.665   0.782  ...
# ..        ...        ...           ...         ...           ...     ...  ...
# 189    160520         10          1963          58         0.608   0.494  ...
# 190    117013         11          1963          61         0.673   0.349  ...
# 191    123480         12          1963          48         0.420   0.372  ...
# 192    110493         13          1963          48         0.455   0.582  ...
# 193    155226         14          1963          74         0.482   0.849  ...
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       1       0.0318        0.5070          0.000000    0.1080    0.968
# 1       0       0.0481        0.2600          0.000000    0.0740    0.912
# 2       1       0.0476        0.3860          0.000000    0.3110    0.866
# 3       1       0.0283        0.0904          0.000004    0.1270    0.912
# 4       0       0.0307        0.1200          0.000004    0.1250    0.731
# ..    ...          ...           ...               ...       ...      ...
# 189     0       0.0345        0.7780          0.000000    0.0926    0.879
# 190     1       0.0368        0.6080          0.000000    0.3800    0.609
# 191     0       0.0327        0.6980          0.000000    0.1040    0.412
# 192     1       0.0292        0.6290          0.000004    0.1720    0.927
# 193     1       0.0452        0.6410          0.000008    0.0414    0.937
#
#        tempo                          Song             Main composer  \
# 0    136.145                FROM ME TO YOU          Lennon/McCartney
# 1     75.533                 SHE LOVES YOU          Lennon/McCartney
# 2    130.726      I WANT TO HOLD YOUR HAND          Lennon/McCartney
# 3     89.847                   I FEEL FINE                    Lennon
# 4    137.453                   DAY TRIPPER                    Lennon
# ..       ...                           ...                       ...
# 189  112.421                 BABY IT'S YOU  David/Williams/Bacharach
# 190  124.451  DO YOU WANT TO KNOW A SECRET                    Lennon
# 191  101.408              A TASTE OF HONEY              Scott/Marlow
# 192  140.928               THERE'S A PLACE                    Lennon
# 193  124.631               TWIST AND SHOUT             Medley/Russel
#
#                Singer
# 0    Lennon/McCartney
# 1    Lennon/McCartney
# 2    Lennon/McCartney
# 3              Lennon
# 4    Lennon/McCartney
# ..                ...
# 189            Lennon
# 190          Harrison
# 191         McCartney
# 192            Lennon
# 193            Lennon
#
# [194 rows x 22 columns]

# %%
## using composite of Main composer and singer, we will assign lead to whoever the greatest singular contributer is
for ind, row in beatles_new.iterrows():
    if (row['Singer'] != 'Lennon' and row['Singer'] != 'McCartney' and row['Singer'] != 'Starr' and row['Singer'] != 'Harrison'):
        beatles_new.loc[ind, 'lead'] = row['Main composer']
    else:
        beatles_new.loc[ind, 'lead'] = row['Singer']

# %%
## last few clean-ups and corrections:
beatles_new.lead[175] = 'Lennon'
beatles_new.lead[16] = 'Lennon/McCartney'
beatles_new.lead[75] = 'Lennon/McCartney'
# Out:
# <ipython-input-110-ff9b161767e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beatles_new.lead[175] = 'Lennon'
# <ipython-input-110-ff9b161767e6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beatles_new.lead[16] = 'Lennon/McCartney'
# <ipython-input-110-ff9b161767e6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beatles_new.lead[75] = 'Lennon/McCartney'

# %%
beatles_new.lead.value_counts()
# Out:
# Lennon              76
# McCartney           69
# Harrison            26
# Lennon/McCartney    13
# Starr               10
# Name: lead, dtype: int64

# %%
beatles_new.groupby('lead')['popularity'].mean()
# Out:
# lead
# Harrison            54.269231
# Lennon              56.263158
# Lennon/McCartney    55.692308
# McCartney           59.318841
# Starr               52.700000
# Name: popularity, dtype: float64

# %%
beatles_new = beatles_new.replace({"key": key_dict, "mode": mode_dict})

# %% [markdown]
# #### Solo career cleaning

# %%
solo_career = pd.read_csv('solo_beatles.csv')

# %%
solo_career.artist.value_counts()
# Out:
# Ringo Starr        166
# Paul McCartney     148
# George Harrison    125
# Wings               82
# John Lennon         78
# Yoko Ono            10
# Name: artist, dtype: int64

# %%
for ind, row in solo_career.iterrows():
    if (row['artist'] == 'Paul McCartney' or row['artist'] == 'Wings'):
        solo_career.loc[ind, 'lead'] = 'McCartney'
    elif (row['artist'] == 'John Lennon' or row['artist'] == 'Yoko One'):
        solo_career.loc[ind, 'lead'] = 'Lennon'
    elif row['artist'] == 'George Harrison':
        solo_career.loc[ind, 'lead'] = 'Harrison'
    else:
        solo_career.loc[ind, 'lead'] = 'Starr'

# %%
solo_career['release_date'] = pd.to_datetime(solo_career['release_date'])
solo_career['release_date'] = solo_career['release_date'].dt.year
solo_career.head(2)
# Out:
#    Unnamed: 0               song          artist               album  \
# 0           0      Dance Tonight  Paul McCartney  Memory Almost Full
# 1           1  Ever Present Past  Paul McCartney  Memory Almost Full
#
#    duration  track_num  release_date  popularity  danceability  energy  key  \
# 0    174933          1          2007          38         0.531   0.891    5
# 1    176293          2          2007          23         0.691   0.755    0
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0431        0.0823           0.00551     0.161    0.926
# 1     1       0.0354        0.0293           0.00000     0.251    0.904
#
#      tempo       lead
# 0  170.973  McCartney
# 1  127.961  McCartney

# %%
solo_career = solo_career.replace({"key": key_dict, "mode": mode_dict})

# %%
band_solo_full_comparison = pd.concat([beatles_new, solo_career], join='inner')

# %%
band_solo_full_comparison.lead.value_counts()
# Out:
# McCartney           299
# Starr               186
# Lennon              154
# Harrison            151
# Lennon/McCartney     13
# Name: lead, dtype: int64

# %%
band_solo_full_comparison.head(2)
# Out:
#    Unnamed: 0            song       artist album  duration  track_num  \
# 0           0  FROM ME TO YOU  The Beatles     1    116160          2
# 1           1   SHE LOVES YOU  The Beatles     1    140920          3
#
#    release_date  popularity  danceability  energy key   mode  speechiness  \
# 0          1963          59         0.581   0.821   C  Major       0.0318
# 1          1963          66         0.377   0.916   E  Minor       0.0481
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.507               0.0     0.108    0.968  136.145
# 1         0.260               0.0     0.074    0.912   75.533
#
#                lead
# 0  Lennon/McCartney
# 1  Lennon/McCartney

# %%
band_solo_full_comparison.groupby('lead')['popularity'].mean()
# Out:
# lead
# Harrison            25.397351
# Lennon              47.240260
# Lennon/McCartney    55.692308
# McCartney           32.347826
# Starr               12.408602
# Name: popularity, dtype: float64

# %% [markdown]
# #### Contemporary group cleanings

# %%
peer_groups = pd.read_csv('peer_groups.csv')
peer_groups.head(2)
# Out:
#    Unnamed: 0            song              artist  \
# 0           0       Rocks Off  The Rolling Stones
# 1           1  Rip This Joint  The Rolling Stones
#
#                                      album  duration  track_num release_date  \
# 0  Exile On Main Street (2010 Re-Mastered)    271933          1   1972-05-12
# 1  Exile On Main Street (2010 Re-Mastered)    143293          2   1972-05-12
#
#    popularity  danceability  energy  key  key_confidence  mode  speechiness  \
# 0          54         0.485   0.943    4           0.464     1       0.0416
# 1          46         0.548   0.952    2           0.809     1       0.0422
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0639             0.179     0.144    0.889  141.982
# 1        0.1180             0.837     0.301    0.906   98.040

# %%
peer_groups['release_date'] = pd.to_datetime(peer_groups['release_date'])
peer_groups['release_date'] = peer_groups['release_date'].dt.year
# Out:
#    Unnamed: 0            song              artist  \
# 0           0       Rocks Off  The Rolling Stones
# 1           1  Rip This Joint  The Rolling Stones
#
#                                      album  duration  track_num  release_date  \
# 0  Exile On Main Street (2010 Re-Mastered)    271933          1          1972
# 1  Exile On Main Street (2010 Re-Mastered)    143293          2          1972
#
#    popularity  danceability  energy  key  key_confidence  mode  speechiness  \
# 0          54         0.485   0.943    4           0.464     1       0.0416
# 1          46         0.548   0.952    2           0.809     1       0.0422
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0639             0.179     0.144    0.889  141.982
# 1        0.1180             0.837     0.301    0.906   98.040

# %%
peer_groups = peer_groups.replace({"key": key_dict, "mode": mode_dict})

# %%
beatles_and_peers_comparison = pd.concat([beatles_new, peer_groups], join='inner')
beatles_and_peers_comparison
# Out:
#      Unnamed: 0                                       song       artist  \
# 0             0                             FROM ME TO YOU  The Beatles
# 1             1                              SHE LOVES YOU  The Beatles
# 2             2                   I WANT TO HOLD YOUR HAND  The Beatles
# 3             3                                I FEEL FINE  The Beatles
# 4             4                                DAY TRIPPER  The Beatles
# ..          ...                                        ...          ...
# 627         627                             I Gotta Go Now    The Kinks
# 628         628                  Things Are Getting Better    The Kinks
# 629         629                      I've Got That Feeling    The Kinks
# 630         630  Too Much Monkey Business - Alternate Take    The Kinks
# 631         631                   I Don't Need You Anymore    The Kinks
#
#      album  duration  track_num  release_date  popularity  danceability  \
# 0        1    116160          2          1963          59         0.581
# 1        1    140920          3          1963          66         0.377
# 2        1    145746          4          1963          71         0.490
# 3        1    139346          7          1964          63         0.564
# 4        1    169000         12          1965          64         0.665
# ..     ...       ...        ...           ...         ...           ...
# 627  Kinks    173226         22          1964          22         0.571
# 628  Kinks    114600         23          1964          21         0.559
# 629  Kinks    162600         24          1964          24         0.574
# 630  Kinks    127893         25          1964          20         0.562
# 631  Kinks    130906         26          1964          23         0.402
#
#      energy key  key_confidence   mode  speechiness  acousticness  \
# 0     0.821   C           0.000  Major       0.0318        0.5070
# 1     0.916   E           0.000  Minor       0.0481        0.2600
# 2     0.715   G           0.560  Major       0.0476        0.3860
# 3     0.827   G           1.000  Major       0.0283        0.0904
# 4     0.782  F#           0.521  Minor       0.0307        0.1200
# ..      ...  ..             ...    ...          ...           ...
# 627   0.514   A           0.365  Major       0.0481        0.2270
# 628   0.869   D           0.443  Major       0.1020        0.1890
# 629   0.763  F#           0.016  Minor       0.0389        0.1870
# 630   0.878   F           0.451  Major       0.1470        0.0213
# 631   0.779   B           0.195  Major       0.0580        0.2080
#
#      instrumentalness  liveness  valence    tempo
# 0            0.000000    0.1080    0.968  136.145
# 1            0.000000    0.0740    0.912   75.533
# 2            0.000000    0.3110    0.866  130.726
# 3            0.000004    0.1270    0.912   89.847
# 4            0.000004    0.1250    0.731  137.453
# ..                ...       ...      ...      ...
# 627          0.000010    0.0709    0.651  106.363
# 628          0.000000    0.0716    0.451  118.696
# 629          0.000000    0.0892    0.852  127.698
# 630          0.000000    0.3690    0.958  117.194
# 631          0.000000    0.1510    0.920  154.169
#
# [826 rows x 19 columns]

# %%
# Out:
# artist
# The Beach Boys        0.537085
# The Beatles           0.539706
# The Kinks             0.550868
# The Rolling Stones    0.639519
# Name: key_confidence, dtype: float64

# %% [markdown]
# #### Final dataframe exports

# %%
#beatles_new.to_csv("beatles_final.csv", sep = ',')
#band_solo_full_comparison.to_csv("band_solo_final.csv", sep = ',')
#beatles_and_peers_comparison.to_csv("band_peers_final.csv", sep = ',')

# %%
beatles_final = pd.read_csv('../data/beatles_final.csv')

# %%
beatles_final.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'song', 'artist', 'album', 'duration',
#        'track_num', 'release_date', 'popularity', 'danceability', 'energy',
#        'key', 'key_confidence', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'Song',
#        'Main composer', 'Singer', 'lead'],
#       dtype='object')

# %%
beatles_corr = beatles_final[['popularity','danceability','duration','energy','acousticness','valence','tempo','key_confidence']]

# %%
beatles_corr.corr()
# Out:
#                 popularity  danceability  duration    energy  acousticness  \
# popularity        1.000000     -0.050159  0.195798 -0.150426     -0.057860
# danceability     -0.050159      1.000000 -0.388155 -0.026133      0.075093
# duration          0.195798     -0.388155  1.000000 -0.020954     -0.156587
# energy           -0.150426     -0.026133 -0.020954  1.000000     -0.488847
# acousticness     -0.057860      0.075093 -0.156587 -0.488847      1.000000
# valence          -0.155559      0.356917 -0.353536  0.441615     -0.056072
# tempo             0.026513     -0.228531  0.008707  0.110907      0.004394
# key_confidence    0.024350      0.011779 -0.097027 -0.095222      0.079596
# liveness         -0.124484     -0.081030  0.092227  0.282949     -0.096401
#
#                  valence     tempo  key_confidence  liveness
# popularity     -0.155559  0.026513        0.024350 -0.124484
# danceability    0.356917 -0.228531        0.011779 -0.081030
# duration       -0.353536  0.008707       -0.097027  0.092227
# energy          0.441615  0.110907       -0.095222  0.282949
# acousticness   -0.056072  0.004394        0.079596 -0.096401
# valence         1.000000  0.002464       -0.023634  0.003978
# tempo           0.002464  1.000000        0.066788 -0.123189
# key_confidence -0.023634  0.066788        1.000000 -0.076426
# liveness        0.003978 -0.123189       -0.076426  1.000000

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = beatles_corr.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(145, 300, s=60, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
